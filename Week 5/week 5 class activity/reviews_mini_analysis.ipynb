# %% [markdown]
# # `app_reviews_demo.csv` — analysis notebook
#
# Run this notebook from the folder that contains **`app_reviews_demo.csv`** (same folder as this file), or change the path inside `pd.read_csv(...)` to match where your CSV lives.

# %%
import pandas as pd
import warnings

warnings.filterwarnings("ignore")

print("pandas version:", pd.__version__)
# Out:
# pandas version: 3.0.2

# %%
df = pd.read_csv("app_reviews_demo.csv")
df.shape
# Out:
# (500, 10)

# %%
df.head()
# Out:
#    id       app             category  rating  \
# 0   1  Fieldkit       field research       1
# 1   2  Fieldkit       field research       2
# 2   3  Lookback        user research       4
# 3   4  Dovetail  research repository       5
# 4   5  Fieldkit       field research       5
#
#                                               review        date  \
# 0  Auto-transcription accuracy on accented speake...  2023-03-31
# 1  Search results are slow when the repository is...  2024-07-28
# 2  One-click export to Notion is a feature I use ...  2024-03-08
# 3  My whole team can comment on the same session ...  2023-12-19
# 4  Works offline and syncs when I get back to WiF...  2024-01-23
#
#    helpful_votes  verified_purchase device_type app_version
# 0             37               True      mobile       2.5.0
# 1             12               True      mobile       2.5.3
# 2             21               True     desktop       5.2.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 500 non-null    int64
#  1   app                500 non-null    str
#  2   category           500 non-null    str
#  3   rating             500 non-null    int64
#  4   review             500 non-null    str
#  5   date               500 non-null    str
#  6   helpful_votes      500 non-null    int64
#  7   verified_purchase  500 non-null    bool
#  8   device_type        437 non-null    str
#  9   app_version        389 non-null    str
# dtypes: bool(1), int64(3), str(6)
# memory usage: 35.8 KB

# %%
# Distribution of ratings (counts + % of rows)
col = "rating"

counts = df[col].value_counts().sort_index()
pct = df[col].value_counts(normalize=True).sort_index().mul(100).round(1)

dist = pd.DataFrame({"count": counts, "pct": pct})
dist
# Out:
#         count   pct
# rating
# 1          29   5.8
# 2          43   8.6
# 3          61  12.2
# 4         160  32.0
# 5         207  41.4

# %%
df.describe(include="all")
# Out:
#                 id   app                  category      rating  \
# count   500.000000   500                       500  500.000000
# unique         NaN     5                         5         NaN
# top            NaN  Miro  collaborative whiteboard         NaN
# freq           NaN   121                       121         NaN
# mean    250.500000   NaN                       NaN    3.946000
# std     144.481833   NaN                       NaN    1.184013
# min       1.000000   NaN                       NaN    1.000000
# 25%     125.750000   NaN                       NaN    3.000000
# 50%     250.500000   NaN                       NaN    4.000000
# 75%     375.250000   NaN                       NaN    5.000000
# max     500.000000   NaN                       NaN    5.000000
#
#                                                    review        date  \
# count                                                 500         500
# ...
